# %%
# %matplotlib inline
from math_lr import *

signal,time = readFile('1.txt')
time = np.linspace(0, 9.99, 1000)
signal = normalize_signal(signal,0)
time,signal = interp_signal(time,signal)

# %%
fourier = np.fft.fft(signal)
fmin,fmax = findBorders(fourier, 0.02)

drawSignal(time, signal, fmin, fmax)

# %%
w0 = 200
am = AM(time,signal,w0)
drawSignal(time,am,-1,-1)

# %%
am = add_noise(am)

# %%
deam = deAM(time,am,w0)
drawSignal(time,deam,-1,-1)

# %%
corr = correlation(deam, signal)
print(corr)
# Out:
# 0.4509763381307154

# %%
stats(time, signal, fmin, fmax)
