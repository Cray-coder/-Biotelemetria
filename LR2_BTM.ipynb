# %%
# %matplotlib inline
from math_lr import *

# %%
signal,time = readFile('1.txt')
time = np.linspace(0, 9.99, 1000)
signal = normalize_signal(signal,0)
fourier = np.fft.fft(signal)
spectrum = np.abs(fourier)
fmin, fmax = findBorders(spectrum, 0.002)
drawSignal(time, signal, fmin, fmax)

# %%
sig = signal - np.min(signal)
tim = TIM(sig, 15)
plt.figure(figsize=(13,8))
plt.plot(tim)
plt.show()

# %%
timeNew, interpol = interp_signal(time,signal)

# %%
plt.figure(figsize=(13,8))
tim = TIM(interpol, 11)
plt.plot(tim[0:1000])
plt.show()

# %%
fourierTIM = np.fft.fft(tim)
spectrumTIM = np.abs(fourierTIM)
plt.plot(spectrumTIM[1:-1])

# %%
fim = FIM(interpol, 3.14, 100, 5)
plt.plot(fim)

# %%
fourierFIM = np.fft.fft(fim)
spectrumFIM = np.abs(fourierFIM)
plt.plot(spectrumFIM[1:-1])
